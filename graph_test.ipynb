# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline  
from graph import Graph
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
params = {}
params['show_prognose'] = True
params['show_cumsum'] = False
params['show_details_flat'] = True
params['show_details_stack'] = False
params['show_table'] = True
params['begroting'] = 100000
     
graph = Graph()
#graph.load(2008101010)
graph.old_load(2015, 2008101010)
plt = graph.realisatie(params)
plt.show()
plt = graph.baten_lasten_pie()
plt.show()
plt = graph.besteed_begroot()
plt.show()
# Out:
# 0.0 (609): SELECT * FROM plan WHERE `Order`=2008101010 AND `Boekjaar`=2015
# 0.03 (610): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (611): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (612): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (613): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (1)
# 0.0 (614): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (1)
# 0.0 (615): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (616): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (617): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (618): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (619): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (2)
# 0.0 (620): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (2)
# 0.0 (621): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (622): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (623): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (624): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (625): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (3)
# 0.0 (626): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (3)
# 0.0 (627): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (628): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (629): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (630): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (631): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (4)
# 0.0 (632): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (4)
# 0.0 (633): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (634): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (635): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (636): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (637): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (5)
# 0.0 (638): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (5)
# 0.0 (639): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (640): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (641): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (642): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (643): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (6)
# 0.0 (644): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (6)
# 0.0 (645): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (646): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (647): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (648): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (649): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (7)
# 0.0 (650): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (7)
# 0.0 (651): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.02 (652): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (653): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (654): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (655): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (8)
# 0.0 (656): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (8)
# 0.0 (657): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (658): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (659): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (660): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (661): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (9)
# 0.0 (662): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (9)
# 0.0 (663): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (664): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (665): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (666): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (667): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (10)
# 0.0 (668): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (10)
# 0.0 (669): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (670): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (671): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (672): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (673): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (11)
# 0.0 (674): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (11)
# 0.0 (675): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (676): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (677): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (678): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (679): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (12)
# 0.0 (680): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (12)
# 0.0 (681): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (682): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (683): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (684): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.04 (685): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (13)
# 0.0 (686): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (13)
# 0.0 (687): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# 0.03 (688): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `geboekt` WHERE `order`=2008101010
# 0.0 (689): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `obligo` WHERE `order`=2008101010
# 0.0 (690): SELECT DISTINCT(`Kostensoort`), `Naam v. kostensoort` FROM `plan` WHERE `order`=2008101010
# 0.03 (691): SELECT * FROM geboekt WHERE `Order`=2008101010 AND `Kostensoort` IN (413120,413155,412105,415146,412140,414185,412120) AND `Jaar` = 2015 AND `Periode` IN (14)
# 0.0 (692): SELECT * FROM obligo WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015 AND `Periode` IN (14)
# 0.0 (693): SELECT * FROM plan WHERE `Order`=2008101010 AND `Kostensoort` IN (411101) AND `Boekjaar` = 2015
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-b091c70618eb> in <module>()
#      10 #graph.load(2008101010)
#      11 graph.old_load(2015, 2008101010)
# ---> 12 plt = graph.realisatie(params)
#      13 plt.show()
#      14 plt = graph.baten_lasten_pie()
#
# P:\niels\FZ\budgerapportages\BudgetRapportage-code\graph.py in realisatie(self, params)
#     132                             rowColours=colors,
#     133                             colLabels=columns,
# --> 134                             loc='bottom')
#     135             the_table.set_fontsize(14)
#     136             the_table.scale(1,2)
#
# C:\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in table(**kwargs)
#    3525 @docstring.copy_dedent(Axes.table)
#    3526 def table(**kwargs):
# -> 3527     ret = gca().table(**kwargs)
#    3528     draw_if_interactive()
#    3529     return ret
#
# C:\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in table(self, **kwargs)
#    5370         %(Table)s
#    5371         """
# -> 5372         return mtable.table(self, **kwargs)
#    5373
#    5374     #### Data analysis
#
# C:\Anaconda\lib\site-packages\matplotlib\table.pyc in table(ax, cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, **kwargs)
#     544             table.add_cell(0, col,
#     545                            width=colWidths[col], height=height,
# --> 546                            text=colLabels[col], facecolor=colColours[col],
#     547                            loc=colLoc)
#     548
#
# IndexError: list index out of range
